# %%
import json
from typing import Dict, Set

import pandas as pd
import yaml
from IPython.display import display
from rapidfuzz import fuzz

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

psg_directory = "../resources/"
psg_data_file = "psgc_2025-08-07.csv"

# %%
df = pd.read_csv(psg_directory + psg_data_file)
display(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43769 entries, 0 to 43768
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   psgc_id                43769 non-null  int64
#  1   name                   43769 non-null  object
#  2   correspondence_code    43719 non-null  float64
#  3   geographic_level       43767 non-null  object
#  4   old_names              1699 non-null   object
#  5   city_class             149 non-null    object
#  6   income_classification  1724 non-null   object
#  7   settlement_type        42011 non-null  object
#  8   population             43762 non-null  object
#  9   Unnamed: 9             75 non-null     object
#  10  barangay_status        2855 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB
# None
#           psgc_id                           name  correspondence_code  \
# 0      1300000000  National Capital Region (NCR)          130000000.0
# 1      1380100000               City of Caloocan          137501000.0
# 2      1380100001                     Barangay 1          137501001.0
# 3      1380100002                     Barangay 2          137501002.0
# 4      1380100003                     Barangay 3          137501003.0
# ...           ...                            ...                  ...
# 43764  1999908006                     Manaulanan          124712037.0
# 43765  1999908007                       Pamalian          124712062.0
# 43766  1999908008                        Tapodoc          124717017.0
# 43767  1999908009                       Macabual          124712034.0
# 43768  1999908010                      Panicupan          124712048.0
#
#       geographic_level old_names city_class income_classification  \
# 0                  Reg       NaN        NaN                   NaN
# 1                 City       NaN        HUC                   1st
# 2                  Bgy       NaN        NaN                   NaN
# 3                  Bgy       NaN        NaN                   NaN
# 4                  Bgy       NaN        NaN                   NaN
# ...                ...       ...        ...                   ...
# 43764              Bgy       NaN        NaN                   NaN
# 43765              Bgy       NaN        NaN                   NaN
# 43766              Bgy       NaN        NaN                   NaN
# 43767              Bgy       NaN        NaN                   NaN
# 43768              Bgy       NaN        NaN                   NaN
#
#       settlement_type     population Unnamed: 9 barangay_status
# 0                 NaN    13,484,462         NaN             NaN
# 1                 NaN     1,661,584         NaN             NaN
# 2                   U         2,319         NaN             NaN
# 3                   U         5,156         NaN             NaN
# 4                   U         2,497         NaN             NaN
# ...               ...            ...        ...             ...
# 43764               U         7,632         NaN             NaN
# 43765               R         3,256         NaN             NaN
# 43766               R         1,767         NaN             NaN
# 43767               R         4,557         NaN             NaN
# 43768               R         2,357         NaN             NaN
#
# [43769 rows x 11 columns]

# %%
df["psgc_id"] = df["psgc_id"].astype(str).str.zfill(10)
df = df.map(lambda x: x.strip() if isinstance(x, str) else x)

geographic_level_map = {
    "Reg":"region",
    "City":"city",
    "Mun":"municipality",
    "Prov":"province",
    "SubMun":"submunicipality", 
    "Bgy":"barangay"
}
df["geographic_level"] = df["geographic_level"].replace(geographic_level_map)

df["barangay_code"] = df["psgc_id"].str[-3:]
df["municipal_or_city_code"] = df["psgc_id"].str[-5:-3]
df["province_or_huc_code"] = df["psgc_id"].str[-8:-5]
df["region_code"] = df["psgc_id"].str[-10:-8]

df["barangay_mapper"] = df["psgc_id"].str[-10:]
df["municipal_or_city_mapper"] = df["psgc_id"].str[-10:-3]
df["province_or_huc_mapper"] = df["psgc_id"].str[-10:-5]
df["region_mapper"] = df["psgc_id"].str[-10:-8]

df.sample(10)

regions_filter = (
    (df["province_or_huc_code"] == "000")
    & (df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)
regions_mapper = (
    df.loc[regions_filter, ["region_mapper", "name"]]
    .sort_values("region_mapper")
    .set_index("region_mapper", drop=True)
    .to_dict()["name"]
)


province_or_huc_filter = (
    ~(df["province_or_huc_code"] == "000")
    & (df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)

province_or_huc_mapper = (
    df.loc[province_or_huc_filter, ["province_or_huc_mapper", "name"]]
    .sort_values("province_or_huc_mapper")
    .set_index("province_or_huc_mapper")
    .to_dict()["name"]
)
municipal_or_city_filter = (
    ~(df["province_or_huc_code"] == "000")
    & ~(df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)

municipal_or_city_mapper = (
    df.loc[municipal_or_city_filter, ["municipal_or_city_mapper", "name"]]
    .sort_values("municipal_or_city_mapper")
    .set_index("municipal_or_city_mapper")
    .to_dict()["name"]
)

df["region"] = df["region_mapper"].map(regions_mapper)
df["province_or_huc"] = df["province_or_huc_mapper"].map(province_or_huc_mapper)
df["municipality_or_city"] = df["municipal_or_city_mapper"].map(municipal_or_city_mapper)
display(df.sample(10))
# Out:
#           psgc_id               name  correspondence_code geographic_level  \
# 12301  0401006031  San Andres Proper           41006031.0         barangay
# 25644  1804609013            Mag-aso           74609013.0         barangay
# 511    1380601229       Barangay 228          133901229.0         barangay
# 32682  0806410012      Santo Rosario           86410012.0         barangay
# 15054  0405617013        Pagsangahan           45617013.0         barangay
# 6050   0105535015          San Roque           15535015.0         barangay
# 42475  1906601006              Bunut          156601006.0         barangay
# 19519  0501725005              Gatbo           51725005.0         barangay
# 10149  0304916032          San Pedro           34916032.0         barangay
# 8376   0203137044        San Vicente           23137044.0         barangay
#
#       old_names city_class income_classification settlement_type population  \
# 12301       NaN        NaN                   NaN               R      2,502
# 25644       NaN        NaN                   NaN               R        887
# 511         NaN        NaN                   NaN               U      3,010
# 32682       NaN        NaN                   NaN               R        894
# 15054       NaN        NaN                   NaN               R      1,733
# 6050        NaN        NaN                   NaN               U      5,600
# 42475       NaN        NaN                   NaN               R      2,200
# 19519       NaN        NaN                   NaN               R      3,097
# 10149       NaN        NaN                   NaN               R      1,660
# 8376        NaN        NaN                   NaN               R      1,738
#
#       Unnamed: 9 barangay_status barangay_code municipal_or_city_code  \
# 12301        NaN             NaN           031                     06
# 25644        NaN             NaN           013                     09
# 511          NaN             NaN           229                     01
# 32682        NaN             NaN           012                     10
# 15054        NaN             NaN           013                     17
# 6050         NaN             NaN           015                     35
# 42475        NaN             NaN           006                     01
# 19519        NaN             NaN           005                     25
# 10149        NaN             NaN           032                     16
# 8376         NaN             NaN           044                     37
#
#       province_or_huc_code region_code barangay_mapper  \
# 12301                  010          04      0401006031
# 25644                  046          18      1804609013
# 511                    806          13      1380601229
# 32682                  064          08      0806410012
# 15054                  056          04      0405617013
# 6050                   055          01      0105535015
# 42475                  066          19      1906601006
# 19519                  017          05      0501725005
# 10149                  049          03      0304916032
# 8376                   031          02      0203137044
#
#       municipal_or_city_mapper province_or_huc_mapper region_mapper  \
# 12301                  0401006                  04010            04
# 25644                  1804609                  18046            18
# 511                    1380601                  13806            13
# 32682                  0806410                  08064            08
# 15054                  0405617                  04056            04
# 6050                   0105535                  01055            01
# 42475                  1906601                  19066            19
# 19519                  0501725                  05017            05
# 10149                  0304916                  03049            03
# 8376                   0203137                  02031            02
#
#                                                   region  province_or_huc  \
# 12301                           Region IV-A (CALABARZON)         Batangas
# 25644                         Negros Island Region (NIR)  Negros Oriental
# 511                        National Capital Region (NCR)   City of Manila
# 32682                      Region VIII (Eastern Visayas)   Southern Leyte
# 15054                           Region IV-A (CALABARZON)           Quezon
# 6050                            Region I (Ilocos Region)       Pangasinan
# 42475  Bangsamoro Autonomous Region In Muslim Mindana...             Sulu
# 19519                            Region V (Bicol Region)    Camarines Sur
# 10149                         Region III (Central Luzon)      Nueva Ecija
# 8376                          Region II (Cagayan Valley)          Isabela
#
#       municipality_or_city
# 12301                Bauan
# 25644                Dauin
# 511             Tondo I/II
# 32682         Padre Burgos
# 15054        General Nakar
# 6050            San Manuel
# 42475              Indanan
# 19519               Ocampo
# 10149                Lupao
# 8376              Tumauini

# %%
clean_mun = (
    df["municipality_or_city"]
    .astype(str)
    .str.lower()
    .str.replace(" ", "")
    .str.replace("(POB.)", "")
)
clean_name = (
    df["name"].astype(str).str.lower().str.replace(" ", "").str.replace("(POB.)", "")
)

df["candidate_hook"] = clean_mun+clean_name

# %%
df
# Out:
#           psgc_id                           name  correspondence_code  \
# 0      1300000000  National Capital Region (NCR)          130000000.0
# 1      1380100000               City of Caloocan          137501000.0
# 2      1380100001                     Barangay 1          137501001.0
# 3      1380100002                     Barangay 2          137501002.0
# 4      1380100003                     Barangay 3          137501003.0
# ...           ...                            ...                  ...
# 43764  1999908006                     Manaulanan          124712037.0
# 43765  1999908007                       Pamalian          124712062.0
# 43766  1999908008                        Tapodoc          124717017.0
# 43767  1999908009                       Macabual          124712034.0
# 43768  1999908010                      Panicupan          124712048.0
#
#       geographic_level old_names city_class income_classification  \
# 0               region       NaN        NaN                   NaN
# 1                 city       NaN        HUC                   1st
# 2             barangay       NaN        NaN                   NaN
# 3             barangay       NaN        NaN                   NaN
# 4             barangay       NaN        NaN                   NaN
# ...                ...       ...        ...                   ...
# 43764         barangay       NaN        NaN                   NaN
# 43765         barangay       NaN        NaN                   NaN
# 43766         barangay       NaN        NaN                   NaN
# 43767         barangay       NaN        NaN                   NaN
# 43768         barangay       NaN        NaN                   NaN
#
#       settlement_type  population Unnamed: 9 barangay_status barangay_code  \
# 0                 NaN  13,484,462        NaN             NaN           000
# 1                 NaN   1,661,584        NaN             NaN           000
# 2                   U       2,319        NaN             NaN           001
# 3                   U       5,156        NaN             NaN           002
# 4                   U       2,497        NaN             NaN           003
# ...               ...         ...        ...             ...           ...
# 43764               U       7,632        NaN             NaN           006
# 43765               R       3,256        NaN             NaN           007
# 43766               R       1,767        NaN             NaN           008
# 43767               R       4,557        NaN             NaN           009
# 43768               R       2,357        NaN             NaN           010
#
#       municipal_or_city_code province_or_huc_code region_code barangay_mapper  \
# 0                         00                  000          13      1300000000
# 1                         00                  801          13      1380100000
# 2                         00                  801          13      1380100001
# 3                         00                  801          13      1380100002
# 4                         00                  801          13      1380100003
# ...                      ...                  ...         ...             ...
# 43764                     08                  999          19      1999908006
# 43765                     08                  999          19      1999908007
# 43766                     08                  999          19      1999908008
# 43767                     08                  999          19      1999908009
# 43768                     08                  999          19      1999908010
#
#       municipal_or_city_mapper province_or_huc_mapper region_mapper  \
# 0                      1300000                  13000            13
# 1                      1380100                  13801            13
# 2                      1380100                  13801            13
# 3                      1380100                  13801            13
# 4                      1380100                  13801            13
# ...                        ...                    ...           ...
# 43764                  1999908                  19999            19
# 43765                  1999908                  19999            19
# 43766                  1999908                  19999            19
# 43767                  1999908                  19999            19
# 43768                  1999908                  19999            19
#
#                                                   region  \
# 0                          National Capital Region (NCR)
# 1                          National Capital Region (NCR)
# 2                          National Capital Region (NCR)
# 3                          National Capital Region (NCR)
# 4                          National Capital Region (NCR)
# ...                                                  ...
# 43764  Bangsamoro Autonomous Region In Muslim Mindana...
# 43765  Bangsamoro Autonomous Region In Muslim Mindana...
# 43766  Bangsamoro Autonomous Region In Muslim Mindana...
# 43767  Bangsamoro Autonomous Region In Muslim Mindana...
# 43768  Bangsamoro Autonomous Region In Muslim Mindana...
#
#                province_or_huc municipality_or_city  \
# 0                          NaN                  NaN
# 1             City of Caloocan                  NaN
# 2             City of Caloocan                  NaN
# 3             City of Caloocan                  NaN
# 4             City of Caloocan                  NaN
# ...                        ...                  ...
# 43764  Special Geographic Area              Tugunan
# 43765  Special Geographic Area              Tugunan
# 43766  Special Geographic Area              Tugunan
# 43767  Special Geographic Area              Tugunan
# 43768  Special Geographic Area              Tugunan
#
#                       candidate_hook
# 0      nannationalcapitalregion(ncr)
# 1                  nancityofcaloocan
# 2                       nanbarangay1
# 3                       nanbarangay2
# 4                       nanbarangay3
# ...                              ...
# 43764              tugunanmanaulanan
# 43765                tugunanpamalian
# 43766                 tugunantapodoc
# 43767                tugunanmacabual
# 43768               tugunanpanicupan
#
# [43769 rows x 23 columns]

# %%
from typing import List
def sanitize_input(input_str: str, exclude: List[str] | str | None = None) -> str:
    """
    Removes whitespaces, lowers, and remove all strings listed in exclude
    """
    sanitized_str = input_str.lower()
    if exclude is None:
        return sanitized_str
    
    if isinstance(exclude, list):
        exclude = [x.lower() for x in exclude if isinstance(x, str)]
        for item in exclude:
            sanitized_str.replace(item, "")
        return sanitized_str
    
    return sanitized_str.replace(exclude.lower(),"")

# %%
input_str = "BACARRALIBTONG"
sanitized_input = sanitize_input(input_str)

df["sanitized_candidate_hook"] = df["candidate_hook"].apply(
    sanitize_input, args=("(pob.)",)
)
df["score"] = df["sanitized_candidate_hook"].apply(fuzz.ratio, args=(sanitized_input,)).round(1)

# %%
df["score"].value_counts().reset_index().sort_values(by="score", ascending=False)
# Out:
#      score  count
# 169  100.0      1
# 183   80.0      1
# 168   76.9      1
# 167   74.3      1
# 154   72.0      2
# ..     ...    ...
# 184    8.7      1
# 171    8.3      1
# 165    7.7      2
# 186    7.4      1
# 182    7.1      1
#
# [187 rows x 2 columns]

# %% [markdown]
# # Loading Masterlist of Schools
# Ginamit ko paid excel sa work to parse data 🤪

# %%
import pandas as pd

# %%
basedf = pd.read_csv("../resources/hidden/dataset.csv", encoding="iso-8859-1")
basedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122396 entries, 0 to 122395
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Id             122396 non-null  object
#  1   Name           122396 non-null  object
#  2   Kind           122396 non-null  object
#  3   Data.Column1   122396 non-null  object
#  4   Data.Column2   122393 non-null  object
#  5   Data.Column3   120886 non-null  object
#  6   Data.Column4   54155 non-null   object
#  7   Data.Column5   59637 non-null   object
#  8   Data.Column6   120764 non-null  object
#  9   Data.Column7   61253 non-null   object
#  10  Data.Column8   122039 non-null  object
#  11  Data.Column9   61441 non-null   object
#  12  Data.Column10  120628 non-null  object
#  13  Data.Column11  61466 non-null   object
#  14  Data.Column12  61469 non-null   object
#  15  Data.Column13  121966 non-null  object
# dtypes: object(16)
# memory usage: 14.9+ MB
# C:\Users\hawitsu\AppData\Local\Temp\ipykernel_5600\211020620.py:1: DtypeWarning: Columns (7,9,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   basedf = pd.read_csv("../resources/hidden/dataset.csv", encoding="iso-8859-1")

# %%
# first 3 rows r empty
df = basedf[3:]     

# all column names were parsed as rows so i have to know where r these column names
filter = df.apply(lambda row: row.isin(["BEIS School ID"]).any(), axis=1)

# now separating per page (kse nga naging row yung header so alam ko na kapag may header
# that's a page boundary)
slicer0 = df.loc[filter].index.to_list()
slicer1 = slicer0[1:] + [900_000]
slicers = zip(slicer0, slicer1)

from typing import List
import numpy as np

# tapos gagawin ko nang unified dataframe
datasets: List[pd.DataFrame] = []
for start, end in slicers:
    datasets.append(df.loc[start:end])

# super messy ng kakalabasan nito there are columns name "Page001" kasi yun ang na-parse
# ni excel so there would be like 500 columns of "Page###" which I don't want to I have
# to remove that as well
for idx, dataset in enumerate(datasets):
    dataset.columns = dataset.iloc[0]
    dataset = dataset.iloc[1:].iloc[:,1:]
    if np.nan in dataset.columns:
        dataset = dataset.drop(np.nan, axis=1)
    for col in dataset.columns:
        if "page" in col.lower():
            dataset = dataset.drop(col, axis=1)
    datasets[idx] = dataset

# %%
from IPython.display import display
from tqdm import tqdm


root_df: pd.DataFrame = pd.DataFrame()
for dataset in tqdm(datasets):
    if "Data.Column1" in dataset.columns:
        display(dataset)
        print("Found Data.Column1")
        break
    try:
        root_df = pd.concat(
            [root_df, dataset]
        )
    except Exception as e:
        display(dataset)
        print("found error")
        print(e)
        break
# Out:
# 100%|██████████| 545/545 [00:00<00:00, 858.37it/s]

# %%
root_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122392 entries, 4 to 122395
# Data columns (total 14 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Region                                       122392 non-null  object
#  1   Division                                     122392 non-null  object
#  2   District                                     120885 non-null  object
#  3   BEIS School ID                               121753 non-null  object
#  4   School Name                                  122384 non-null  object
#  5   Street Address                               118887 non-null  object
#  6   Municipality                                 122386 non-null  object
#  7   Legislative District                         61467 non-null   object
#  8   Barangay                                     61416 non-null   object
#  9   Sector                                       61467 non-null   object
#  10  Urban/Ru r                                   61242 non-null   object
#  11  School Subclassification                     58643 non-null   object
#  12  Modified Curricural Offering Classification  43836 non-null   object
#  13  Table                                        60924 non-null   object
# dtypes: object(14)
# memory usage: 13.1+ MB

# %%
root_df
# Out:
#           Region         Division         District BEIS School ID  \
# 4       Region I     Ilocos Norte        Bacarra I         100001
# 5       Region I     Ilocos Norte        Bacarra I         100002
# 6       Region I     Ilocos Norte        Bacarra I         100003
# 7       Region I     Ilocos Norte        Bacarra I         100004
# 8       Region I     Ilocos Norte        Bacarra I         100005
# ...          ...              ...              ...            ...
# 122391       NCR  Muntinlupa City  Muntinlupa Ci t         488533
# 122392       NCR  Muntinlupa City  Muntinlupa Ci t         488544
# 122393       NCR  Muntinlupa City  Muntinlupa Ci t         488547
# 122394       NCR  Muntinlupa City  Muntinlupa Ci t         488548
# 122395       NCR  Muntinlupa City  Muntinlupa Ci t         488559
#
#                                               School Name  \
# 4                                      Apaleng-Libtong ES
# 5                                             Bacarra CES
# 6                                                Buyon ES
# 7                               Ganagan Elementary School
# 8                                              Macupit ES
# ...                                                   ...
# 122391                        CBC Integrated School, Inc.
# 122392                    The Linden Tree Institute, Inc.
# 122393  Cambridge Children's Learning and Development ...
# 122394                         Holy Word Christian School
# 122395                         Edith Learning Center Inc.
#
#                                            Street Address        Municipality  \
# 4                Brgy. 21, Libtong, Bacarra, Ilocos Norte             BACARRA
# 5                                              Santa Rita             BACARRA
# 6                                                    NONE             BACARRA
# 7                       #37 Ganagan,Bacarra, Ilocos Norte             BACARRA
# 8                                                 Macupit             BACARRA
# ...                                                   ...                 ...
# 122391           1560 Estanislao Street, Lakeview Homes I  CITY OF MUNTINLUPA
# 122392                              177 Buencamino Street  CITY OF MUNTINLUPA
# 122393             Lower Ground Level Alabang Town Center  CITY OF MUNTINLUPA
# 122394   4 Cattleya St., Doña Rosario Bayview Subdivision  CITY OF MUNTINLUPA
# 122395  Unit 101-102 Ground Floor, Kennedy Center Buil...  CITY OF MUNTINLUPA
#
#        Legislative District           Barangay  Sector     Urban/Ru r  \
# 4              1st District            LIBTONG  Public  Partially U r
# 5              1st District  SANTA RITA (POB.)  Public  Partially U r
# 6              1st District              BUYON  Public  Partially U r
# 7              1st District            GANAGAN  Public  Partially U r
# 8              1st District            MACUPIT  Public  Partially U r
# ...                     ...                ...     ...            ...
# 122391                  NaN                NaN     NaN            NaN
# 122392                  NaN                NaN     NaN            NaN
# 122393                  NaN                NaN     NaN            NaN
# 122394                  NaN                NaN     NaN            NaN
# 122395                  NaN                NaN     NaN            NaN
#
#        School Subclassification Modified Curricural Offering Classification  \
# 4                 DepED Managed                                   Purely ES
# 5                 DepED Managed                                   Purely ES
# 6                 DepED Managed                                   Purely ES
# 7                 DepED Managed                                   Purely ES
# 8                 DepED Managed                                   Purely ES
# ...                         ...                                         ...
# 122391                      NaN                                         NaN
# 122392                      NaN                                         NaN
# 122393                      NaN                                         NaN
# 122394                      NaN                                         NaN
# 122395                      NaN                                         NaN
#
#         Table
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# ...       ...
# 122391  Table
# 122392  Table
# 122393  Table
# 122394  Table
# 122395  Table
#
# [122392 rows x 14 columns]

# %%
basedf.loc[122391]
# Out:
# Id                                               Table001
# Name                                Table001 (Page 1-544)
# Kind                                                Table
# Data.Column1                                          NCR
# Data.Column2                              Muntinlupa City
# Data.Column3                              Muntinlupa Ci t
# Data.Column4                                          NaN
# Data.Column5                                          NaN
# Data.Column6                                       488533
# Data.Column7                                          NaN
# Data.Column8                  CBC Integrated School, Inc.
# Data.Column9                                          NaN
# Data.Column10    1560 Estanislao Street, Lakeview Homes I
# Data.Column11                                         NaN
# Data.Column12                                         NaN
# Data.Column13                          CITY OF MUNTINLUPA
# Name: 122391, dtype: object

# %% [markdown]
# ## Damn, I feel like this is too messy. Maybe excel might not be the best tool to use to parse the data????

# %%
# let's try tabula-py
import tabula

# %%
df = tabula.read_pdf("../resources/hidden/masterlist.pdf", pages="all")

# %%
from tqdm import tqdm
root_df = pd.DataFrame()
for idx, d in enumerate(tqdm(df)):
    d["page"] = idx 
    root_df = pd.concat([root_df, d])
# Out:
# 100%|██████████| 544/544 [00:03<00:00, 176.82it/s]

# %%
root_df = root_df.reset_index(drop=True)

# %%
root_df[root_df["BEIS School ID"].str.strip().str.isnumeric().notna()]
# Out:
#          Region         Division       District       BEIS School ID  \
# 0      Region I     Ilocos Norte      Bacarra I               100001
# 1      Region I     Ilocos Norte      Bacarra I               100002
# 2      Region I     Ilocos Norte      Bacarra I               100003
# 3      Region I     Ilocos Norte      Bacarra I               100004
# 4      Region I     Ilocos Norte      Bacarra I               100005
# ...         ...              ...            ...                  ...
# 60919       NCR  Muntinlupa City  Muntinlupa Ci  y District II488533
# 60920       NCR  Muntinlupa City  Muntinlupa Ci  y District II488544
# 60921       NCR  Muntinlupa City  Muntinlupa Ci  y District II488547
# 60922       NCR  Muntinlupa City  Muntinlupa Ci  y District II488548
# 60923       NCR  Muntinlupa City  Muntinlupa Ci  y District II488559
#
#                                              School Name  \
# 0                                     Apaleng-Libtong ES
# 1                                            Bacarra CES
# 2                                               Buyon ES
# 3                              Ganagan Elementary School
# 4                                             Macupit ES
# ...                                                  ...
# 60919                        CBC Integrated School, Inc.
# 60920                    The Linden Tree Institute, Inc.
# 60921  Cambridge Children's Learning and Development ...
# 60922                         Holy Word Christian School
# 60923                         Edith Learning Center Inc.
#
#                                           Street Address  \
# 0               Brgy. 21, Libtong, Bacarra, Ilocos Norte
# 1                                             Santa Rita
# 2                                                   NONE
# 3                      #37 Ganagan,Bacarra, Ilocos Norte
# 4                                                Macupit
# ...                                                  ...
# 60919           1560 Estanislao Street, Lakeview Homes I
# 60920                              177 Buencamino Street
# 60921             Lower Ground Level Alabang Town Center
# 60922   4 Cattleya St., Doña Rosario Bayview Subdivision
# 60923  Unit 101-102 Ground Floor, Kennedy Center Buil...
#
#                    Municipality Legislative District           Barangay  \
# 0                       BACARRA         1st District            LIBTONG
# 1                       BACARRA         1st District  SANTA RITA (POB.)
# 2                       BACARRA         1st District              BUYON
# 3                       BACARRA         1st District            GANAGAN
# 4                       BACARRA         1st District            MACUPIT
# ...                         ...                  ...                ...
# 60919        CITY OF MUNTINLUPA        Lone District            PUTATAN
# 60920        CITY OF MUNTINLUPA        Lone District            ALABANG
# 60921        CITY OF MUNTINLUPA        Lone District            ALABANG
# 60922        CITY OF MUNTINLUPA        Lone District              SUCAT
# 60923  CPIaTrYk  O2F MUNTINLUPA        Lone District            ALABANG
#
#         Sector     Urban/Ru Sacl hColaosls Sifuicbactliaosnsification  \
# 0       Public  Partially U                          bDaenpED Managed
# 1       Public  Partially U                          bDaenpED Managed
# 2       Public  Partially U                          bDaenpED Managed
# 3       Public  Partially U                          bDaenpED Managed
# 4       Public  Partially U                          bDaenpED Managed
# ...        ...          ...                                       ...
# 60919  Private        Urban                             Non-Sectarian
# 60920  Private        Urban                             Non-Sectarian
# 60921  Private        Urban                                 Sectarian
# 60922  Private        Urban                                 Sectarian
# 60923  Private        Urban                             Non-Sectarian
#
#       Modified Curricural Offering Classification  page
# 0                                       Purely ES     0
# 1                                       Purely ES     0
# 2                                       Purely ES     0
# 3                                       Purely ES     0
# 4                                       Purely ES     0
# ...                                           ...   ...
# 60919                                   Purely ES   543
# 60920                        ES and JHS (K to 10)   543
# 60921                                   Purely ES   543
# 60922                        ES and JHS (K to 10)   543
# 60923                                   Purely ES   543
#
# [33596 rows x 14 columns]

# %% [markdown]
# boom it fucken worked

# %% [markdown]
# ### Data Cleaning
